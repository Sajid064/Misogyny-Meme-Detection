jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/500.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/156.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/380.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/558.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/120.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/629.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/290.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/124.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/441.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/924.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/512.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/59.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/819.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/595.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/379.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/313.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/480.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/527.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/248.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/230.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/580.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/509.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/872.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/776.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/247.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/477.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/94.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/904.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/932.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/362.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/60.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/538.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/221.jpg
# /kaggle/input/mmzippy/train-20250110T130852Z-001/train/167.jpg
# ...
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/975.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1185.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/309.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1776.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/895.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/365.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/312.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1360.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/184.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1477.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/862.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/300.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/250.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/914.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/583.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1769.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1526.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1427.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1600.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/297.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/556.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1232.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/711.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1691.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/540.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/855.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/493.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/125.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1085.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1014.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1240.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/128.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/172.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/95.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/553.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/3.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1049.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/442.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1566.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/36.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/train.csv
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1342.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1344.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/910.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1213.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/610.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/838.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/217.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/615.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/536.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/657.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1375.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1116.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1311.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/386.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/600.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1591.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/902.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/144.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1316.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1030.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1766.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1008.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1020.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/923.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/662.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/110.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1753.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/941.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/655.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/964.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/413.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/407.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1245.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1464.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1723.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/325.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/510.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/739.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/437.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/724.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/896.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/712.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/812.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/385.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/625.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1628.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1623.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/63.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1560.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/731.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/621.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/927.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/733.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1231.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/398.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/782.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1419.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/888.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1506.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1568.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1476.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1306.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1524.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/231.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1365.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1356.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1403.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1500.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1199.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1176.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/19.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/303.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/725.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1519.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/514.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/866.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/87.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/873.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/562.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/282.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/93.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/470.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1441.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1720.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/170.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1253.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/857.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/983.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1444.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1456.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1653.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1065.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/324.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1609.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/457.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/803.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1530.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1246.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1115.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1377.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1284.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/860.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1179.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1333.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/268.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1120.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/517.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1276.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/526.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1741.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/607.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/345.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/316.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/226.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1052.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1553.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1114.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/740.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1525.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/637.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/462.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/116.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/898.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1768.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1516.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1195.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1633.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1367.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1334.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/827.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1732.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/78.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1220.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/367.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1513.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/899.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1542.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/861.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1552.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/460.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1005.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/648.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/883.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1587.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1394.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/49.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/890.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1442.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/796.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/203.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1693.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1147.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/640.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1184.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1390.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1046.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/679.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1264.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/714.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1407.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/505.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1425.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1578.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1717.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/298.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1662.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1467.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/483.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1681.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1504.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/647.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1612.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1689.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1204.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1057.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1322.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/504.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/129.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/735.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/205.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/133.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/304.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/551.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1165.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/315.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1090.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1358.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/810.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1061.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1445.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1155.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/987.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/635.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1135.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/830.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1399.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1283.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/597.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/461.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1021.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1015.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1236.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1141.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/925.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/454.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/605.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/754.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/753.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/599.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/147.jpg
# /kaggle/input/mmzippy/train-20250106T133515Z-001/train/1656.jpg

# %%
# !pip install openpyxl
# !pip install gdown
# !pip install farasapy
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Collecting farasapy
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farasapy) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farasapy) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farasapy) (2024.12.14)
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Installing collected packages: farasapy
# Successfully installed farasapy-0.0.14

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Dropout, Concatenate, BatchNormalization, GlobalAveragePooling1D
from tensorflow.keras.applications import EfficientNetB7, MobileNetV2, ResNet50 
from tensorflow.keras.optimizers import Adam
from transformers import BertTokenizer, TFBertModel
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import load_img, img_to_array
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from tensorflow.keras.layers import Multiply, Add

# %%
# Set paths for CSV and image directories
train_csv_path = '/kaggle/input/mmzippy/train-20250110T130852Z-001/train/train.csv'
dev_csv_path = '/kaggle/input/mmzippy/dev-20250110T130931Z-001/dev/dev.csv'
test_csv_path = '/kaggle/input/mmzippy/test_with_labels-20250128T173317Z-001/test_with_labels/test_with_labels.csv'

train_image_dir = '/kaggle/input/mmzippy/train-20250110T130852Z-001/train/'
dev_image_dir = '/kaggle/input/mmzippy/dev-20250110T130931Z-001/dev'
test_image_dir = '/kaggle/input/mmzippy/test-20250110T131009Z-001/test'

# Load CSV files
train_df = pd.read_csv(train_csv_path)
dev_df = pd.read_csv(dev_csv_path)
test_df = pd.read_csv(test_csv_path)

# %%
train_df.head()
# Out:
#    image_id  labels                                     transcriptions
# 0       888       0  \nഈ ചാടി ഓടി നടക്കണ മനുഷ്യനാണോടാ നിങ്ങളിത്രേം ...
# 1       554       1  മലയാള സിനിമയുടെ ഭാവി വടറാണി ഇവൾ തന്നെ നല്ല കുഴ...
# 2       556       1  ഒന്ന് പെറ്റത് ആണെങ്കിലും .. മുലയും വയറും ചാടിയ...
# 3       484       1  ഓൺലൈൻ പരിചയപ്പെട്ടവനെ കളി തരാമെന്ന് പറഞ്ഞു അപ്...
# 4       370       0  കാമുകിയും അൺലിമിറ്റഡ് നെറ്റ് ഓഫറുംഉള്ള പയ്യന്റ...

# %%
# Assuming train_df contains the labels in the 'labels' column
print("Number of 0s:", train_df['labels'].value_counts().get(0, 0))
print("Number of 1s:", train_df['labels'].value_counts().get(1, 0))
# Out:
# Number of 0s: 381
# Number of 1s: 259

# %%
# Assuming train_df contains the labels in the 'labels' column
print("Number of 0s:", dev_df['labels'].value_counts().get(0, 0))
print("Number of 1s:", dev_df['labels'].value_counts().get(1, 0))
# Out:
# Number of 0s: 97
# Number of 1s: 63

# %%
# Assuming train_df contains the labels in the 'labels' column
print("Number of 0s:", test_df['labels'].value_counts().get(0, 0))
print("Number of 1s:", test_df['labels'].value_counts().get(1, 0))
# Out:
# Number of 0s: 122
# Number of 1s: 78

# %%
# Function to load image and preprocess it
def load_image(img_path):
    try:
        img = load_img(img_path, target_size=(224, 224))  # Resize image to fit EfficientNetB0
        img_array = img_to_array(img)
        img_array = img_array / 255.0  # Normalize the image
        return img_array
    except Exception as e:
        print(f"Error loading image {img_path}: {e}")
        return None

# Function to load images from a given folder
def load_images_from_folder(image_dir, img_ids):
    images = []
    for img_id in img_ids:
        img_path = os.path.join(image_dir, f"{img_id}.jpg")  # Assuming image is in JPG format
        img = load_image(img_path)
        if img is not None:  # Check if the image was loaded successfully
            images.append(img)
    return np.array(images)

# Prepare images and labels for each dataset
train_images = load_images_from_folder(train_image_dir, train_df['image_id'])
dev_images = load_images_from_folder(dev_image_dir, dev_df['image_id'])

# Check if images were loaded successfully
if train_images.size == 0:
    print("No train images were loaded.")
if dev_images.size == 0:
    print("No dev images were loaded.")

# Prepare labels for train and dev sets
y_train = train_df['labels'].values  # Ensure 'labels' column exists
y_dev = dev_df['labels'].values

# Prepare text data (transcriptions) for each dataset
texts_train = train_df['transcriptions'].values  # Ensure 'transcriptions' column exists
texts_dev = dev_df['transcriptions'].values

# %%
# Load BERT tokenizer and model (Multilingual BERT for Malayalam language)
bert_model_name = 'l3cube-pune/malayalam-bert'  # mBERT for multilingual support
bert_tokenizer = BertTokenizer.from_pretrained(bert_model_name)
bert_model = TFBertModel.from_pretrained(bert_model_name)

# Custom BERT Layer
class BERTLayer(tf.keras.layers.Layer):
    def __init__(self, bert_model, **kwargs):
        super(BERTLayer, self).__init__(**kwargs)
        self.bert_model = bert_model
    
    def call(self, inputs):
        input_ids, attention_mask = inputs
        output = self.bert_model(input_ids=input_ids, attention_mask=attention_mask)
        return output.pooler_output  # Optionally: output.last_hidden_state for sequence-level tasks

# Image model (EfficientNetB0 backbone)
image_input = Input(shape=(224, 224, 3), name="image_input")
base_model = EfficientNetB7(weights='imagenet', include_top=False, input_tensor=image_input)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.4)(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)

# Text model (BERT processing)
MAX_LENGTH = 128  # Define maximum length for text sequences

text_input_ids = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name="text_input_ids")
text_attention_mask = Input(shape=(MAX_LENGTH,), dtype=tf.int32, name="text_attention_mask")

# Pass text inputs through BERT model
bert_output = BERTLayer(bert_model)([text_input_ids, text_attention_mask])
y = Dense(512, activation='relu')(bert_output)
y = BatchNormalization()(y)
y = Dropout(0.4)(y)
y = Dense(256, activation='relu')(y)
y = BatchNormalization()(y)
y = Dropout(0.2)(y)

# Cross-Modal Fusion with Attention
def cross_modal_attention(image_features, text_features):
    """Applies cross-modal attention between image and text features."""
    # Compute attention scores
    attention_image_to_text = Dense(256, activation="softmax")(image_features)
    attention_text_to_image = Dense(256, activation="softmax")(text_features)

    # Weighted fusion
    attended_image = Multiply()([image_features, attention_text_to_image])
    attended_text = Multiply()([text_features, attention_image_to_text])

    # Concatenate attended features
    fused_features = Concatenate()([attended_image, attended_text])
    return fused_features

# Apply cross-modal fusion
fused_features = cross_modal_attention(x, y)

# Final dense layers
z = Dense(256, activation='relu')(fused_features)
z = Dropout(0.3)(z)
z = Dense(128, activation='relu')(z)
z = Dropout(0.2)(z)
z = Dense(1, activation='sigmoid')(z)  # Sigmoid output for binary classification

# Create the final model
model = Model(inputs=[image_input, text_input_ids, text_attention_mask], outputs=z)

# Compile the model
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# Define callbacks
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',         
    factor=0.5,                 
    patience=3,                 
    min_lr=1e-7,                
    verbose=1                    
)

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10, 
    restore_best_weights=True
)

# Preprocessing function for BERT tokenizer
def preprocess_text_with_bert_tokenizer(texts, tokenizer, max_length):
    """Preprocess text data using BERT tokenizer."""
    encoding = tokenizer(
        texts.tolist(),
        return_tensors="tf",
        padding='max_length',
        max_length=max_length,
        truncation=True
    )
    return encoding['input_ids'], encoding['attention_mask']

# Preprocess train and validation texts
train_input_ids, train_attention_mask = preprocess_text_with_bert_tokenizer(train_df['transcriptions'], bert_tokenizer, MAX_LENGTH)
dev_input_ids, dev_attention_mask = preprocess_text_with_bert_tokenizer(dev_df['transcriptions'], bert_tokenizer, MAX_LENGTH)
# Out:
# tokenizer_config.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/3.16M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/6.41M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/664 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/951M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'bert.embeddings.position_ids', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertModel were not initialized from the PyTorch model and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step

# %%
# Prepare the training data (assuming train_images and dev_images are preprocessed image arrays)
X_train = {
    "image_input": train_images,  # Preprocessed images
    "text_input_ids": train_input_ids,  # Input ids from BERT tokenizer
    "text_attention_mask": train_attention_mask  # Attention mask for BERT
}
X_dev = {
    "image_input": dev_images,  # Preprocessed images
    "text_input_ids": dev_input_ids,  # Input ids from BERT tokenizer
    "text_attention_mask": dev_attention_mask  # Attention mask for BERT
}

# Labels
y_train = train_df['labels'].values  # Binary labels
y_dev = dev_df['labels'].values

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_dev, y_dev),
    epochs=100,
    batch_size=8,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# Epoch 1/100

# %%
# Predict on the validation set
y_pred_probs = model.predict(X_dev)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()  # Convert probabilities to binary predictions

# Print classification report
print("Validation Report:")
print(classification_report(y_dev, y_pred, target_names=['Class 0', 'Class 1']))

# Calculate and print overall metrics
accuracy = accuracy_score(y_dev, y_pred)
precision = precision_score(y_dev, y_pred)
recall = recall_score(y_dev, y_pred)
f1 = f1_score(y_dev, y_pred)

print(f"Overall Accuracy: {accuracy:.4f}")
print(f"Overall Precision: {precision:.4f}")
print(f"Overall Recall: {recall:.4f}")
print(f"Overall F1-Score: {f1:.4f}")

# %%
# Prepare test images and text data
test_images = load_images_from_folder(test_image_dir, test_df['image_id'])

# Preprocess test text data with BERT tokenizer
test_input_ids, test_attention_mask = preprocess_text_with_bert_tokenizer(test_df['transcriptions'], bert_tokenizer, MAX_LENGTH)


# Make predictions on the test set
X_test = {
    "image_input": test_images,
    "text_input_ids": test_input_ids,
    "text_attention_mask": test_attention_mask
}

y_test = test_df['labels'].values

# Make predictions on the test set
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int)  # Convert to binary prediction (0 or 1)

# Print classification report
print("Validation Report:")
print(classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1']))

# Save predictions to a CSV
test_predictions = pd.DataFrame({
    'image_id': test_df['image_id'],
    'predicted_label': y_pred.flatten()  # Flatten to remove extra dimension
})

test_predictions.to_csv('/kaggle/working/Fired_from_NLP_Malayalam_run1.csv', header=False, index=False)

# Display some training images and their labels
def visualize_images(image_paths, labels, n=5):
    plt.figure(figsize=(15, 5))
    for i in range(n):
        ax = plt.subplot(1, n, i+1)
        img = load_img(image_paths[i], target_size=(224, 224))
        plt.imshow(img)
        plt.title(f"Label: {'Misogyny' if labels[i] == 1 else 'Non-Misogyny'}")
        plt.axis('off')
    plt.show()

# Visualize some images
sample_image_paths = [os.path.join(train_image_dir, f"{img_id}.jpg") for img_id in train_df['image_id'].head(5)]
visualize_images(sample_image_paths, y_train[:5])

# %%
# Calculate and print the F1 score separately
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1:.4f}")
